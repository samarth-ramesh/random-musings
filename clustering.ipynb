# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
with open("./data.txt", "r") as fp:
    data = fp.readlines()
    data = tuple(map(lambda d : d.split(), data))
    data = tuple(map(lambda d: tuple(map(lambda x: int(x), d)), data))
arr = np.array(data)
# arr = np.transpose(data)

# %%
plt.scatter(arr[0], arr[1])

# %%
km = KMeans(n_clusters=50, init='random')
arr2 = km.fit_predict(arr)

# %%
clusters = {}

for i in range(len(arr)):
    if not (arr2[i] in clusters):
        clusters[arr2[i]] = ([], [])
    clusters[arr2[i]][0].append(arr[i][0])
    clusters[arr2[i]][1].append(arr[i][1])
# Out:
# ([14920, 11758, 12244, 11707, 10932, 10055, 10793, 11346, 12329, 11304, 10547, 10895, 10511, 10968, 12700, 11648, 12093, 11266, 11972, 11504, 9596, 11608, 12909, 11133, 12548, 12271, 10670, 11233, 10681, 12640, 11504, 10893, 11636, 12866, 10864, 11402, 10935, 11738, 11476, 10457, 13815, 12447, 11303, 12291, 10909, 10215, 12231, 12056, 12989, 10754, 11001, 10219, 10075, 11682, 13322, 11021, 10981, 11749, 11138, 10896, 10714, 13033, 14242], [50298, 49219, 49180, 50831, 49591, 48235, 49879, 49957, 48590, 50748, 48630, 49868, 49865, 50319, 50715, 50442, 50390, 47149, 49353, 49504, 47780, 49849, 50774, 48302, 51547, 50801, 49473, 50321, 48326, 49781, 49613, 49089, 49520, 49685, 47595, 49037, 49427, 49383, 47853, 49183, 48988, 51465, 50343, 48192, 50127, 49540, 48044, 49839, 48969, 48878, 48738, 49251, 48613, 49377, 49302, 50533, 49305, 48185, 48042, 49165, 49809, 46582, 47449])

# %%
for v in clusters.values():
    plt.scatter(v[0], v[1])
